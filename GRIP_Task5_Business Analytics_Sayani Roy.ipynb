# %% [markdown]
# # GRIP Task 5: To explore Business Analytics

# %% [markdown]
# # By Sayani Roy

# %% [markdown]
# # Problem:
# ## You are the business owner of the retail firm and want to seehow your company is performing. You are interested in finding out the weak areas where you can work to make more profit. What all business problems you can derive by looking into the data?

# %% [markdown]
# # ‘Exploratory Data Analysis’ has been performed on the provided dataset ‘SampleSuperstore' to solve this problem.

# %% [markdown]
# ## Importing the Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Importing the Dataset

# %%
df = pd.read_csv('C:/Users/Shelly/Desktop/SAYANI/GRIP/SampleSuperstore.csv')

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480

# %% [markdown]
# ## Checking the Dimensions of the dataframe

# %%
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# #### There are 13 features in total.

# %% [markdown]
# ## Summarising the Dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# #### Number of numerical features = 5

# %% [markdown]
# ## Checking for Null Values

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# #### No missing values in any column

# %% [markdown]
# ## Checking for Duplicate Records

# %%
duplicate=df.duplicated()
print(duplicate.sum())
df[duplicate]
# Out:
# 17
#            Ship Mode      Segment        Country           City         State  \
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 3406  Standard Class  Home Office  United States       Columbus          Ohio
# 3670  Standard Class     Consumer  United States          Salem        Oregon
# 4117  Standard Class     Consumer  United States    Los Angeles    California
# 4553  Standard Class     Consumer  United States  San Francisco    California
# 5905        Same Day  Home Office  United States  San Francisco    California
# 6146  Standard Class    Corporate  United States  San Francisco    California
# 6334  Standard Class     Consumer  United States  New York City      New York
# 6357  Standard Class    Corporate  United States        Seattle    Washington
# 7608  Standard Class     Consumer  United States  San Francisco    California
# 7735  Standard Class    Corporate  United States        Seattle    Washington
# 7759  Standard Class    Corporate  United States        Houston         Texas
# 8032     First Class     Consumer  United States        Houston         Texas
# 8095    Second Class     Consumer  United States        Seattle    Washington
# 9262  Standard Class     Consumer  United States        Detroit      Michigan
# 9363  Standard Class  Home Office  United States        Seattle    Washington
# 9477    Second Class    Corporate  United States        Chicago      Illinois
#
#       Postal Code   Region         Category Sub-Category    Sales  Quantity  \
# 950         19120     East  Office Supplies        Paper   15.552         3
# 3406        43229     East        Furniture       Chairs  281.372         2
# 3670        97301     West  Office Supplies        Paper   10.368         2
# 4117        90036     West  Office Supplies        Paper   19.440         3
# 4553        94122     West  Office Supplies        Paper   12.840         3
# 5905        94122     West  Office Supplies       Labels   41.400         4
# 6146        94122     West  Office Supplies          Art   11.760         4
# 6334        10011     East  Office Supplies        Paper   49.120         4
# 6357        98103     West  Office Supplies        Paper   25.920         4
# 7608        94122     West  Office Supplies        Paper   25.920         4
# 7735        98105     West  Office Supplies        Paper   19.440         3
# 7759        77041  Central  Office Supplies        Paper   15.552         3
# 8032        77041  Central  Office Supplies        Paper   47.952         3
# 8095        98115     West  Office Supplies        Paper   12.960         2
# 9262        48227  Central        Furniture       Chairs  389.970         3
# 9363        98105     West        Furniture  Furnishings   22.140         3
# 9477        60653  Central  Office Supplies      Binders    3.564         3
#
#       Discount   Profit
# 950        0.2   5.4432
# 3406       0.3 -12.0588
# 3670       0.2   3.6288
# 4117       0.0   9.3312
# 4553       0.0   5.7780
# 5905       0.0  19.8720
# 6146       0.0   3.1752
# 6334       0.0  23.0864
# 6357       0.0  12.4416
# 7608       0.0  12.4416
# 7735       0.0   9.3312
# 7759       0.2   5.4432
# 8032       0.2  16.1838
# 8095       0.0   6.2208
# 9262       0.0  35.0973
# 9363       0.0   6.4206
# 9477       0.8  -6.2370

# %% [markdown]
# Since we have 17 duplicate records in the data, we will remove this from the data set so that we get only distinct records.

# %% [markdown]
# ## Dropping Duplicate Values

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# Post removing the duplicate, we will check whether the duplicates have been removed from the data set or not.

# %%
dpl = df.duplicated()
dpl.sum()
# Out:
# 0

# %% [markdown]
# #### Hence, duplicate values have been removed.

# %% [markdown]
# ## Checking for Unique Values

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# Postal Codes are not needed for our analysis.
# So let us drop the 'Postal Codes' column

# %% [markdown]
# ## Dropping the 'Postal Codes Column'

# %%
col=['Postal Code']
df1=df.drop(columns=col, axis=1)

# %% [markdown]
# ## Checking the Summary Statistics

# %%
df1.describe()
# Out:
#               Sales     Quantity     Discount      Profit
# count   9977.000000  9977.000000  9977.000000  9977.00000
# mean     230.148902     3.790719     0.156278    28.69013
# std      623.721409     2.226657     0.206455   234.45784
# min        0.444000     1.000000     0.000000 -6599.97800
# 25%       17.300000     2.000000     0.000000     1.72620
# 50%       54.816000     3.000000     0.200000     8.67100
# 75%      209.970000     5.000000     0.200000    29.37200
# max    22638.480000    14.000000     0.800000  8399.97600

# %% [markdown]
# ## Visualising the Histograms

# %%
df1.hist(figsize=(10, 10), bins=50)
plt.show()

# %% [markdown]
# ## Pairplots between the Sales, Quantity, Discount rate and Profit

# %%
sns.set()
sns.pairplot(df1, height = 2.5)
plt.show()

# %% [markdown]
# ## Correlation between the Sales, Quantity, Discount rate and Profit

# %%
df1.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200722 -0.028311  0.479067
# Quantity  0.200722  1.000000  0.008678  0.066211
# Discount -0.028311  0.008678  1.000000 -0.219662
# Profit    0.479067  0.066211 -0.219662  1.000000

# %%
corr = df1.corr()
sns.heatmap(corr,annot=True)

# %% [markdown]
# ## Plotting the Number of Orders for each Ship Mode

# %%
sns.countplot(df1['Ship Mode'])
plt.show()

# %% [markdown]
# ## Plotting the Number of Orders for each Segment

# %%
sns.countplot(df1['Segment'])
plt.show()

# %% [markdown]
# ## Plotting the Number of Orders for each Region

# %%
sns.countplot(df1['Region'])
plt.show()

# %% [markdown]
# ## Plotting the Number of Orders for each Category

# %%
sns.countplot(df1['Category'])
plt.show()

# %% [markdown]
# ## Plotting the Number of Orders for each Sub-Category

# %%
grouped = df1.groupby(['Category','Sub-Category'])
grouped.size()
# Out:
# Category         Sub-Category
# Furniture        Bookcases        228
#                  Chairs           615
#                  Furnishings      956
#                  Tables           319
# Office Supplies  Appliances       466
#                  Art              795
#                  Binders         1522
#                  Envelopes        254
#                  Fasteners        217
#                  Labels           363
#                  Paper           1359
#                  Storage          846
#                  Supplies         190
# Technology       Accessories      775
#                  Copiers           68
#                  Machines         115
#                  Phones           889
# dtype: int64

# %%
subcategory_table = pd.crosstab(index=df1["Category"], 
                          columns=df1["Sub-Category"])

subcategory_table
# Out:
# Sub-Category     Accessories  Appliances  Art  Binders  Bookcases  Chairs  \
# Category
# Furniture                  0           0    0        0        228     615
# Office Supplies            0         466  795     1522          0       0
# Technology               775           0    0        0          0       0
#
# Sub-Category     Copiers  Envelopes  Fasteners  Furnishings  Labels  Machines  \
# Category
# Furniture              0          0          0          956       0         0
# Office Supplies        0        254        217            0     363         0
# Technology            68          0          0            0       0       115
#
# Sub-Category     Paper  Phones  Storage  Supplies  Tables
# Category
# Furniture            0       0        0         0     319
# Office Supplies   1359       0      846       190       0
# Technology           0     889        0         0       0

# %%
subcategory_table.plot(kind="bar", 
                 figsize=(8,8),
                 stacked=True)

# %% [markdown]
# ## Plotting the Number of Orders for each State

# %%
df1['State'].value_counts().plot(kind = 'bar', figsize=(20,10))

# %% [markdown]
# ## Finding out the number of Orders in each City

# %%
df1['City'].value_counts()
# Out:
# New York City    914
# Los Angeles      746
# Philadelphia     536
# San Francisco    506
# Seattle          424
#                 ...
# Kissimmee          1
# Davis              1
# Antioch            1
# Conway             1
# Linden             1
# Name: City, Length: 531, dtype: int64

# %% [markdown]
# ## Plotting the top 30 Cities with the most number of orders

# %%
df1['City'].value_counts().head(30).plot(kind = 'bar', figsize=(20,10))

# %% [markdown]
# ## QUANTITIES

# %% [markdown]
# ## Quantities ordered by Ship Modes

# %%
df.shipmode = df.groupby('Ship Mode')['Quantity'].sum().reset_index()
print(df.shipmode)
# Out:
#         Ship Mode  Quantity
# 0     First Class      5690
# 1        Same Day      1956
# 2    Second Class      7418
# 3  Standard Class     22756

# %%
shipmode_quantity=pd.DataFrame(df.groupby('Ship Mode').sum()['Quantity'])
labels=df.shipmode['Ship Mode'].unique()
plt.figure(figsize=(5,5))
plt.pie(df.shipmode['Quantity'], labels=shipmode_quantity.index, autopct='%1.1f%%', explode=(0.02, 0.02, 0.02, 0.02),)
plt.title('Quantities ordered by Ship Modes', size=15)
# Out:
# Text(0.5, 1.0, 'Quantities ordered by Ship Modes')

# %% [markdown]
# #### Majority of the quantities ordered was shipped by the Standard Class.

# %% [markdown]
# ## Quantities ordered by Segment

# %%
df.segment = df.groupby('Segment')['Quantity'].sum().reset_index()
print(df.segment)
# Out:
#        Segment  Quantity
# 0     Consumer     19497
# 1    Corporate     11591
# 2  Home Office      6732

# %%
segment_quantity=pd.DataFrame(df.groupby('Segment').sum()['Quantity'])
labels=df.segment['Segment'].unique()
plt.figure(figsize=(5,5))
plt.pie(df.segment['Quantity'], labels=segment_quantity.index, autopct='%1.1f%%', explode=(0.02, 0.02, 0.02),)
plt.title('Quantities ordered by Segment', size=15)
# Out:
# Text(0.5, 1.0, 'Quantities ordered by Segment')

# %% [markdown]
# #### The lowest quantities of goods have been ordered from the Home Office segment.

# %% [markdown]
# ## Quantities ordered by Region

# %%
df.region = df.groupby('Region')['Quantity'].sum().reset_index()
print(df.region)
# Out:
#     Region  Quantity
# 0  Central      8768
# 1     East     10609
# 2    South      6209
# 3     West     12234

# %%
region_quantity=pd.DataFrame(df.groupby('Region').sum()['Quantity'])
labels=df.region['Region'].unique()
plt.figure(figsize=(5,5))
plt.pie(df.region['Quantity'], labels=region_quantity.index, autopct='%1.1f%%', explode=(0.02, 0.02, 0.02, 0.02),)
plt.title('Quantities ordered by Region', size=15)
# Out:
# Text(0.5, 1.0, 'Quantities ordered by Region')

# %% [markdown]
# #### As we can see from the pie-chart, the Western region has ordered the highest quantity of goods, while the Southern region has ordered the lowest quantity of goods.

# %% [markdown]
# ## Quantities ordered by Categories

# %%
df.category = df.groupby('Category')['Quantity'].sum().reset_index()
print(df.category)
# Out:
#           Category  Quantity
# 0        Furniture      8020
# 1  Office Supplies     22861
# 2       Technology      6939

# %%
category_quantity=pd.DataFrame(df.groupby('Category').sum()['Quantity'])
labels=df.category['Category'].unique()
plt.figure(figsize=(5,5))
plt.pie(df.category['Quantity'], labels=category_quantity.index, autopct='%1.1f%%', explode=(0.02, 0.02, 0.02),)
plt.title('Quantities ordered by Categories', size=15)
# Out:
# Text(0.5, 1.0, 'Quantities ordered by Categories')

# %% [markdown]
# #### The category with the lowest quantity of orders: Technology

# %% [markdown]
# ## Quantities ordered by Sub-Categories

# %%
df.subcategory = df.groupby('Sub-Category')['Quantity'].sum().reset_index()
print(df.subcategory)
# Out:
#    Sub-Category  Quantity
# 0   Accessories      2976
# 1    Appliances      1729
# 2           Art      2996
# 3       Binders      5971
# 4     Bookcases       868
# 5        Chairs      2351
# 6       Copiers       234
# 7     Envelopes       906
# 8     Fasteners       914
# 9   Furnishings      3560
# 10       Labels      1396
# 11     Machines       440
# 12        Paper      5144
# 13       Phones      3289
# 14      Storage      3158
# 15     Supplies       647
# 16       Tables      1241

# %%
subcategory_quantity=pd.DataFrame(df.groupby('Sub-Category').sum()['Quantity'])
labels=df.subcategory['Sub-Category'].unique()
plt.figure(figsize=(12,12))
plt.pie(df.subcategory['Quantity'], labels=subcategory_quantity.index,)
plt.title('Quantities ordered by Sub-Categories', size=15)
# Out:
# Text(0.5, 1.0, 'Quantities ordered by Sub-Categories')

# %% [markdown]
# #### The sub-category with the lowest quantity of orders: Copiers

# %% [markdown]
# ## Quantities ordered by the States

# %%
states_quantity=df.groupby('State')['Quantity'].sum().reset_index().sort_values(by='Quantity', ascending=False)

# %% [markdown]
# ### Top 10 States in terms of Quantities:

# %%
top10_states_quantity=states_quantity.head(10)
sns.catplot('State', 'Quantity', data=top10_states_quantity, kind='bar', aspect=2, height=8, palette="mako")

# %% [markdown]
# #### California has ordered the highest quantity of goods.

# %% [markdown]
# ### Bottom 5 States in terms of Quantities:

# %%
bottom5_states_quantity=states_quantity.tail(5)
sns.catplot('State', 'Quantity', data=bottom5_states_quantity, kind='bar', aspect=4, height=6, palette="mako")

# %% [markdown]
# #### Wyoming has ordered the lowest quantity of goods.

# %% [markdown]
# ## Quantities ordered by the Cities

# %%
cities_quantity=df.groupby('City')['Quantity'].sum().reset_index().sort_values(by='Quantity', ascending=False)

# %% [markdown]
# ### Top 20 Cities in terms of Quantities ordered:

# %%
top20_cities_quantity=cities_quantity.head(20)
sns.catplot('City', 'Quantity', data=top20_cities_quantity, kind='bar', aspect=2, height=8, palette="mako")

# %% [markdown]
# #### New York has ordered the highest quantity of goods, followed by Los Angeles.

# %% [markdown]
# ### Bottom 10 Cities in terms of Quantities ordered:

# %%
bottom10_cities_quantity=cities_quantity.tail(10)
sns.catplot('City', 'Quantity', data=bottom10_cities_quantity, kind='bar', aspect=4, height=4, palette="mako")

# %% [markdown]
# #### Jupiter, lowa City, Port Orange, Lindenhurst, Littleton and Elyria have ordered the lowest quantity of goods.

# %% [markdown]
# # SALES

# %% [markdown]
# ## Ship Mode-wise Sales

# %%
df.shipmodesales = df.groupby('Ship Mode')['Sales'].sum().reset_index()
print(df.shipmodesales)
# Out:
#         Ship Mode         Sales
# 0     First Class  3.513805e+05
# 1        Same Day  1.283217e+05
# 2    Second Class  4.591770e+05
# 3  Standard Class  1.357316e+06

# %%
shipmode_sales=pd.DataFrame(df.groupby('Ship Mode').sum()['Sales'])
labels=df.shipmodesales['Ship Mode'].unique()
plt.figure(figsize=(5,5))
plt.pie(df.shipmodesales['Sales'], labels=shipmode_sales.index, autopct='%.2f', explode=(0.02, 0.02, 0.02, 0.02), radius=1.2)
centre_circle=plt.Circle((0,0), 0.90, fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Sales ordered by Ship Modes', size=15)
# Out:
# Text(0.5, 1.0, 'Sales ordered by Ship Modes')

# %% [markdown]
# #### 'Same Day' ship mode accounted for a very low portion of sales.

# %% [markdown]
# ## Segment-wise Sales

# %%
df.segmentsales = df.groupby('Segment')['Sales'].sum().reset_index()
print(df.segmentsales)
# Out:
#        Segment         Sales
# 0     Consumer  1.160833e+06
# 1    Corporate  7.060701e+05
# 2  Home Office  4.292927e+05

# %%
segment_sales=pd.DataFrame(df.groupby('Segment').sum()['Sales'])
labels=df.segmentsales['Segment'].unique()
plt.figure(figsize=(6,6))
plt.pie(df.segmentsales['Sales'], labels=segment_sales.index, autopct='%.2f', explode=(0.02, 0.02, 0.02), radius=1.2)
centre_circle=plt.Circle((0,0), 0.90, fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)

# %% [markdown]
# #### The least amount of sales have been generated by the Home Office segment.

# %% [markdown]
# ## Region-wise Sales

# %%
df.regionsales = df.groupby('Region')['Sales'].sum().reset_index()
print(df.regionsales)
# Out:
#     Region        Sales
# 0  Central  500782.8528
# 1     East  678435.1960
# 2    South  391721.9050
# 3     West  725255.6365

# %%
region_sales=pd.DataFrame(df.groupby('Region').sum()['Sales'])
labels=df.regionsales['Region'].unique()
plt.figure(figsize=(5,5))
plt.pie(df.regionsales['Sales'], labels=region_sales.index, autopct='%.2f', explode=(0.02, 0.02, 0.02, 0.02), radius=1.2)
centre_circle=plt.Circle((0,0), 0.90, fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Sales ordered by Regions', size=15)
# Out:
# Text(0.5, 1.0, 'Sales ordered by Regions')

# %% [markdown]
# #### The Southern region has the lowest sales, while the Central region comes a close second lowest.

# %% [markdown]
# ## Category-wise Sales

# %%
df.categorysales = df.groupby('Category')['Sales'].sum().reset_index()
print(df.categorysales)
# Out:
#           Category        Sales
# 0        Furniture  741306.3133
# 1  Office Supplies  718735.2440
# 2       Technology  836154.0330

# %%
category_sales=pd.DataFrame(df.groupby('Category').sum()['Sales'])
labels=df.categorysales['Category'].unique()
plt.figure(figsize=(5,5))
plt.pie(df.categorysales['Sales'], labels=category_sales.index, autopct='%.2f', explode=(0.02, 0.02, 0.02), radius=1.2)
centre_circle=plt.Circle((0,0), 0.90, fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Sales ordered by Categories', size=15)
# Out:
# Text(0.5, 1.0, 'Sales ordered by Categories')

# %% [markdown]
# #### Office Supplies have accounted for the lowest proportion of sales.

# %% [markdown]
# ## Sub-Category-wise Sales

# %%
df.subcategorysales = df.groupby('Sub-Category')['Sales'].sum().reset_index()
print(df.subcategorysales)
# Out:
#    Sub-Category        Sales
# 0   Accessories  167380.3180
# 1    Appliances  107532.1610
# 2           Art   27107.0320
# 3       Binders  203409.1690
# 4     Bookcases  114879.9963
# 5        Chairs  327777.7610
# 6       Copiers  149528.0300
# 7     Envelopes   16476.4020
# 8     Fasteners    3024.2800
# 9   Furnishings   91683.0240
# 10       Labels   12444.9120
# 11     Machines  189238.6310
# 12        Paper   78224.1420
# 13       Phones  330007.0540
# 14      Storage  223843.6080
# 15     Supplies   46673.5380
# 16       Tables  206965.5320

# %%
subcategory_sales=pd.DataFrame(df.groupby('Sub-Category').sum()['Sales'])
labels=df.subcategorysales['Sub-Category'].unique()
plt.figure(figsize=(15,15))
plt.pie(df.subcategorysales['Sales'], labels=subcategory_sales.index, autopct='%.2f', radius=1.2)
centre_circle=plt.Circle((0,0), 0.90, fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Sales ordered by Sub-Categories', size=15)
# Out:
# Text(0.5, 1.0, 'Sales ordered by Sub-Categories')

# %% [markdown]
# #### Fasteners have accounted for the lowest proportion of sales among the sub-categories.

# %% [markdown]
# ## Sales ordered by the States

# %%
states_sales=df.groupby('State')['Sales'].sum().reset_index().sort_values(by='Sales', ascending=False)

# %% [markdown]
# ### Top 10 States in terms of Sale:

# %%
top10_states_sales=states_sales.head(10)
sns.catplot('State', 'Sales', data=top10_states_sales, kind='bar', aspect=2, height=4, palette="magma")

# %% [markdown]
# #### California has the highest sales.

# %% [markdown]
# ### Bottom 5 States in terms of Sales

# %%
bottom5_states_quantity=states_sales.tail(5)
sns.catplot('State', 'Sales', data=bottom5_states_quantity, kind='bar', aspect=2, height=4, palette="magma")

# %% [markdown]
# #### North Dakota has the lowest sales

# %% [markdown]
# ## Sales ordered by the Cities

# %%
cities_sales=df.groupby('City')['Sales'].sum().reset_index().sort_values(by='Sales', ascending=False)

# %% [markdown]
# ### Top 20 Cities in terms of Sales:

# %%
top20_cities_sales=cities_sales.head(20)
sns.catplot('City', 'Sales', data=top20_cities_sales, kind='bar', aspect=3, height=8, palette="magma")

# %% [markdown]
# #### New York is also the city with the highest sales, followed by Los Angeles again.

# %% [markdown]
# ### Bottom 10 Cities in terms of Sales:

# %%
bottom10_cities_sales=cities_sales.tail(10)
sns.catplot('City', 'Sales', data=bottom10_cities_sales, kind='bar', aspect=4, height=4, palette="magma")

# %% [markdown]
# #### Abilene is the city with the lowesr sales, followed by Elyria and then Jupiter.

# %% [markdown]
# # DISCOUNTS

# %% [markdown]
# ## Average Discount across Ship Modes

# %%
df.shipmodedisc = df.groupby('Ship Mode')['Discount'].agg(np.mean).reset_index().sort_values(by='Discount', ascending=False)
print(df.shipmodedisc)
# Out:
#         Ship Mode  Discount
# 0     First Class  0.164587
# 3  Standard Class  0.160222
# 1        Same Day  0.152675
# 2    Second Class  0.138626

# %%
(markerline, stemlines, baseline) = plt.stem(df.shipmodedisc['Ship Mode'],
                                             df.shipmodedisc['Discount'], use_line_collection=True)
plt.setp(markerline, marker='*', markersize=15,
         markeredgewidth=2, color='gold')
plt.setp(stemlines, color='gold')
plt.setp(baseline, visible=False)

plt.tick_params(labelsize=12)
plt.xlabel('Ship Mode', size=12)
plt.ylabel('Discount', size=12)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# #### Most discounted Ship Mode: First Class

# %% [markdown]
# ## Average Discount across Segments

# %%
df.segmentdisc = df.groupby('Segment')['Discount'].agg(np.mean).reset_index().sort_values(by='Discount', ascending=False)
print(df.segmentdisc)
# Out:
#        Segment  Discount
# 0     Consumer  0.158308
# 1    Corporate  0.158159
# 2  Home Office  0.147178

# %%
(markerline, stemlines, baseline) = plt.stem(df.segmentdisc['Segment'],
                                             df.segmentdisc['Discount'], use_line_collection=True)
plt.setp(markerline, marker='*', markersize=15,
         markeredgewidth=2, color='gold')
plt.setp(stemlines, color='gold')
plt.setp(baseline, visible=False)

plt.tick_params(labelsize=12)
plt.xlabel('Segment', size=12)
plt.ylabel('Discount', size=12)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# #### There is no major differences in the average discount rates across the segments.

# %% [markdown]
# ## Average Discount across Regions

# %%
df.regiondisc = df.groupby('Region')['Discount'].agg(np.mean).reset_index().sort_values(by='Discount', ascending=False)
print(df.regiondisc)
# Out:
#     Region  Discount
# 0  Central  0.240250
# 2    South  0.147253
# 1     East  0.145343
# 3     West  0.109615

# %%
(markerline, stemlines, baseline) = plt.stem(df.regiondisc['Region'],
                                             df.regiondisc['Discount'], use_line_collection=True)
plt.setp(markerline, marker='*', markersize=15,
         markeredgewidth=2, color='gold')
plt.setp(stemlines, color='gold')
plt.setp(baseline, visible=False)

plt.tick_params(labelsize=12)
plt.xlabel('Region', size=12)
plt.ylabel('Discount', size=12)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# #### The Central Region has received the highest discounts, while the Western Region has received the lowest discounts on an average.

# %% [markdown]
# ## Average Discount across Categories

# %%
df.categorydisc = df.groupby('Category')['Discount'].agg(np.mean).reset_index().sort_values(by='Discount', ascending=False)
print(df.categorydisc)
# Out:
#           Category  Discount
# 0        Furniture  0.174027
# 1  Office Supplies  0.157385
# 2       Technology  0.132323

# %%
(markerline, stemlines, baseline) = plt.stem(df.categorydisc['Category'],
                                             df.categorydisc['Discount'], use_line_collection=True)
plt.setp(markerline, marker='*', markersize=15,
         markeredgewidth=2, color='gold')
plt.setp(stemlines, color='gold')
plt.setp(baseline, visible=False)

plt.tick_params(labelsize=12)
plt.xlabel('Category', size=12)
plt.ylabel('Discount', size=12)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# #### Most discounted Category: Furniture

# %% [markdown]
# ## Average Discount across Sub-Categories

# %%
df.subcategorydisc = df.groupby('Sub-Category')['Discount'].agg(np.mean).reset_index().sort_values(by='Discount', ascending=False)
print(df.subcategorydisc)
# Out:
#    Sub-Category  Discount
# 3       Binders  0.372011
# 11     Machines  0.306087
# 16       Tables  0.261285
# 4     Bookcases  0.211140
# 5        Chairs  0.170244
# 1    Appliances  0.166524
# 6       Copiers  0.161765
# 13       Phones  0.154556
# 9   Furnishings  0.138494
# 8     Fasteners  0.082028
# 7     Envelopes  0.080315
# 0   Accessories  0.078452
# 15     Supplies  0.076842
# 2           Art  0.074969
# 12        Paper  0.074908
# 14      Storage  0.074704
# 10       Labels  0.068871

# %%
plt.figure(figsize=(15,15))
(markerline, stemlines, baseline) = plt.stem(df.subcategorydisc['Sub-Category'],
                                             df.subcategorydisc['Discount'], use_line_collection=True)
plt.setp(markerline, marker='*', markersize=15,
         markeredgewidth=2, color='gold')
plt.setp(stemlines, color='gold')
plt.setp(baseline, visible=False)

plt.tick_params(labelsize=12)
plt.xlabel('Sub-Category', size=12)
plt.ylabel('Discount', size=12)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# #### Most discounted product: Binders

# %% [markdown]
# ## Average Discount across States

# %%
df.statedisc = df.groupby('State')['Discount'].agg(np.mean).reset_index().sort_values(by='Discount', ascending=False)

# %% [markdown]
# ### Top 10 States with the highest Average Discounts:

# %%
top10_states_disc=df.statedisc.head(10)
print(top10_states_disc)
# Out:
#              State  Discount
# 11        Illinois  0.389206
# 41           Texas  0.370539
# 36    Pennsylvania  0.328840
# 33            Ohio  0.325000
# 4         Colorado  0.316484
# 1          Arizona  0.303571
# 8          Florida  0.299347
# 40       Tennessee  0.291257
# 35          Oregon  0.289431
# 31  North Carolina  0.283534

# %%
plt.figure(figsize=(25,5))
(markerline, stemlines, baseline) = plt.stem(top10_states_disc['State'],
                                             top10_states_disc['Discount'], use_line_collection=True)
plt.setp(markerline, marker='*', markersize=15,
         markeredgewidth=2, color='gold')
plt.setp(stemlines, color='gold')
plt.setp(baseline, visible=False)

plt.tick_params(labelsize=12)
plt.xlabel('State', size=12)
plt.ylabel('Discount', size=12)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# #### The state of Illinois has been offered the highest average discount.

# %% [markdown]
# ## Average Discount across Cities

# %%
df.citydisc = df.groupby('City')['Discount'].agg(np.mean).reset_index().sort_values(by='Discount', ascending=False)

# %% [markdown]
# ### Top 20 Cities with the highest Average Discounts:

# %%
top20_cities_disc=df.citydisc.head(20)
print(top20_cities_disc)
# Out:
#                City  Discount
# 1           Abilene  0.800000
# 117       Deer Park  0.800000
# 417      Romeoville  0.800000
# 305   Missouri City  0.800000
# 140          Elyria  0.700000
# 370       Pensacola  0.700000
# 354    Ormond Beach  0.700000
# 259       Littleton  0.700000
# 493           Tyler  0.640000
# 55            Bryan  0.616667
# 355          Oswego  0.600000
# 71        Champaign  0.600000
# 484     Tinley Park  0.600000
# 182      Grove City  0.550000
# 284           Mason  0.533333
# 108  Cuyahoga Falls  0.533333
# 294        Mesquite  0.520000
# 502            Waco  0.520000
# 392          Pueblo  0.512500
# 413        Rockford  0.509091

# %%
plt.figure(figsize=(25,5))
(markerline, stemlines, baseline) = plt.stem(top20_cities_disc['City'],
                                             top20_cities_disc['Discount'], use_line_collection=True)
plt.setp(markerline, marker='*', markersize=15,
         markeredgewidth=2, color='gold')
plt.setp(stemlines, color='gold')
plt.setp(baseline, visible=False)

plt.tick_params(labelsize=12)
plt.xlabel('City', size=12)
plt.ylabel('Discount', size=12)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# #### Abilene,  Deer Park, Romeoville and Missouri City have been offered the highest discounts on an average.

# %% [markdown]
# # PROFITS

# %% [markdown]
# ## Profits ordered by Ship Modes

# %%
shipmode_profit=df.groupby('Ship Mode')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %%
sns.catplot('Ship Mode', 'Profit', data=shipmode_profit, kind='bar', aspect=2, height=4, palette="rocket")

# %% [markdown]
# #### The 'Same Day' ship mide has generated the lowest profits in total.

# %% [markdown]
# ## Profits ordered by Segments

# %%
segment_profit=df.groupby('Segment')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %%
sns.catplot('Segment', 'Profit', data=segment_profit, kind='bar', aspect=2, height=4, palette="rocket")

# %% [markdown]
# #### Least profitable segment: Home Office

# %% [markdown]
# # Profits ordered by Region

# %%
region_profit=df.groupby('Region')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %%
sns.catplot('Region', 'Profit', data=region_profit, kind='bar', aspect=2, height=4, palette="rocket")

# %% [markdown]
# #### The Central region is the least profitable among the four regions.

# %% [markdown]
# ## Profits ordered by Categories

# %%
category_profit=df.groupby('Category')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %%
sns.catplot('Category', 'Profit', data=category_profit, kind='bar', aspect=2, height=4, palette="rocket")

# %% [markdown]
# #### Technology is the most profitable category, while Furniture is the least profitable category.

# %% [markdown]
# ## Profits ordered by Sub-Categories

# %%
subcategory_profit=df.groupby('Sub-Category')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %%
sns.catplot('Sub-Category', 'Profit', data=subcategory_profit, kind='bar', aspect=1, height=18, palette="rocket")

# %% [markdown]
# #### The most profitable product: Copiers
# #### The least profitable product: Fasteners
# #### The product with the highest loss: Tables

# %% [markdown]
# ## Profits ordered by States

# %%
states_profit=df.groupby('State')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %% [markdown]
# ### Top 10 States in terms of Profits:

# %%
top10_states_profit=states_profit.head(10)
sns.catplot('State', 'Profit', data=top10_states_profit, kind='bar', aspect=2, height=5, palette="rocket")

# %% [markdown]
# #### The store has earned the highest profit from the state of California. New York comes a close second.

# %% [markdown]
# ### Bottom 5 States in terms of Profit:

# %%
bottom5_states_profit=states_profit.tail(5)
sns.catplot('State', 'Profit', data=bottom5_states_profit, kind='bar', aspect=2, height=4, palette="rocket")

# %% [markdown]
# #### Among the states, the highest loss has been incurred from Texas.

# %% [markdown]
# ## Profits ordered by Cities

# %%
cities_profit=df.groupby('City')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %% [markdown]
# ### Top 20 Cities in terms of Profit:

# %%
top20_cities_profit=cities_profit.head(20)
sns.catplot('City', 'Profit', data=top20_cities_profit, kind='bar', aspect=2, height=8, palette="rocket")

# %% [markdown]
# #### The highest profit has been made from New York City.

# %%
bottom10_cities_profit=cities_profit.tail(10)
sns.catplot('City', 'Profit', data=bottom10_cities_profit, kind='bar', aspect=4, height=6, palette="rocket")

# %% [markdown]
# #### The store has faced a loss from many cities. The highest loss has been incurred from Philadelphia.

# %% [markdown]
# # RESULTS:

# %% [markdown]
# ### Among the segments 'Home Office' is the least ordered, also generating the lowest sales and the lowest profits.

# %% [markdown]
# ### Among the four regions, South has ordered the lowest, followed by the Central. The Southern region has also generated the lowest sales. The Central region has generated the lowest profits, inspite of being offered the highest discounts on an average.

# %% [markdown]
# ### Among the Categories, 'Furnitures' have generated the lowest profits inspite of being the most discounted. 'Technologies', on the other hand, though the least ordered, have generated the highest profit.

# %% [markdown]
# ### Tables, Bookcases and Supplies have generated losses. Higher discount rates were also provided for Tables.

# %% [markdown]
# ### Among the states, Wyoming and West Virginia ranked the lowest in terms of the quantities of orders and the total sales generated. These four states - Texas, Illinois, Pennyslavania and Ohio - generated the least sales even after being offered very high discounts.

# %% [markdown]
# ### Among the Cities, Philadelphia and Houston recorded the highest losses.
